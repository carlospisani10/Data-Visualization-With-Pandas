# %%
# Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
import pandas as pd

# %%
crime = pd.read_csv("Resources/crime_data.csv")
crime= crime.sample(frac=1).reset_index(drop=True)
crime.head()
# Out:
#      year   population  violent crime  violent crime rate  \
# 0  2011.0  311587816.0      1206005.0               387.1
# 1  2013.0  316128839.0      1163146.0               367.9
# 2  2001.0  285317559.0      1439480.0               504.5
# 3  1994.0  260327021.0      1857670.0               713.6
# 4  2010.0  309330219.0      1251248.0               404.5
#
#    murder and non-negligent manslaughter  \
# 0                                14661.0
# 1                                14196.0
# 2                                16037.0
# 3                                23326.0
# 4                                14722.0
#
#     murder and non-negligent manslaughter rate      rape  rape rate   robbery  \
# 0                                          4.7   84175.0       27.0  354746.0
# 1                                          4.5   79770.0       25.2  345031.0
# 2                                          5.6   90863.0       31.8  423557.0
# ...

# %%
year_series = crime.iloc[:, 0]

# %%
violent_series = crime.iloc[:, 3]
(vc_slope, vc_int, _, _, _) = linregression()
